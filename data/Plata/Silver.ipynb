# %%
from google.colab import drive
drive.mount('/content/drive')

import os, pandas as pd

BASE   = "/content/drive/MyDrive/TFM"
RAW    = f"{BASE}/Raw"
BRONCE = f"{BASE}/bronce"
PLATA  = f"{BASE}/plata"
ORO    = f"{BASE}/oro"
os.makedirs(PLATA, exist_ok=True)   # ajusta la carpeta según el notebook
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

BRONCE = "/content/drive/MyDrive/Master/TFM TUI 3/Bronce"

for t in ["Familia_POI", "Familia_Restaurantes", "Familia_Restaurantes_terrazas", "Familia_Paradas"]:
    df = pd.read_parquet(f"{BRONCE}/{t}.parquet")
    print(f"\n===== {t}  ({len(df)} filas) =====")
    print(list(df.columns))
    print(df.head(3).to_string())
# Out:
# ===== Familia_POI  (1402 filas) =====
# ['PK', 'NOMBRE', 'DESCRIPCION-ENTIDAD', 'HORARIO', 'EQUIPAMIENTO', 'TRANSPORTE', 'DESCRIPCION', 'ACCESIBILIDAD', 'CONTENT-URL', 'NOMBRE-VIA', 'CLASE-VIAL', 'TIPO-NUM', 'NUM', 'PLANTA', 'PUERTA', 'ESCALERAS', 'ORIENTACION', 'LOCALIDAD', 'PROVINCIA', 'CODIGO-POSTAL', 'COD-BARRIO', 'BARRIO', 'COD-DISTRITO', 'DISTRITO', 'COORDENADA-X', 'COORDENADA-Y', 'LATITUD', 'LONGITUD', 'TELEFONO', 'FAX', 'EMAIL', 'TIPO', '_fichero_origen', 'categoria', 'PDF']
# ...
